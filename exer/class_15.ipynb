# %%
import pandas as pd
import numpy as np
from pandas import datetime
from matplotlib import pyplot as plt



"""
Load AirQualityUCI Data
"""

def parser(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

input_file = r'C:\Users\edwsq\Desktop\AirQualityUCI_refined.csv'

df = pd.read_csv(input_file,
                 index_col=[0],
                 parse_dates=[0],
                 date_parser=parser)

df.head()
# Out:
# <ipython-input-38-f810e795730d>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
#                      CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  \
# Datetime
# 2004-03-10 18:00:00     2.6       1360.0         1046.0    166.0
# 2004-03-10 19:00:00     2.0       1292.0          955.0    103.0
# 2004-03-10 20:00:00     2.2       1402.0          939.0    131.0
# 2004-03-10 21:00:00     2.2       1376.0          948.0    172.0
# 2004-03-10 22:00:00     1.6       1272.0          836.0    131.0
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH  \
# Datetime
# 2004-03-10 18:00:00        1056.0    113.0        1692.0       1268.0  48.9
# 2004-03-10 19:00:00        1174.0     92.0        1559.0        972.0  47.7
# 2004-03-10 20:00:00        1140.0    114.0        1555.0       1074.0  54.0
# 2004-03-10 21:00:00        1092.0    122.0        1584.0       1203.0  60.0
# 2004-03-10 22:00:00        1205.0    116.0        1490.0       1110.0  59.6
#
#                          AH  C6H6(GT)
# Datetime
# 2004-03-10 18:00:00  0.7578      11.9
# 2004-03-10 19:00:00  0.7255       9.4
# 2004-03-10 20:00:00  0.7502       9.0
# 2004-03-10 21:00:00  0.7867       9.2
# 2004-03-10 22:00:00  0.7888       6.5

# %%
# Visualization setup
# %matplotlib
# %config InlineBackend.figure_format = 'svg'

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]
plt.ion() # enable the interactive mode

import seaborn as sns
sns.set()  # set plot styles
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# Visualize the 'CO(GT)' column
df['CO(GT)'].interpolate(inplace=True)


"""
Binning
"""

max_val = df['CO(GT)'].max()
min_val = df['CO(GT)'].min()
print(max_val, min_val)
# Out:
# 11.9 0.0

# %%
# Make interval values
bins = np.linspace(min_val, max_val, 6)
bins
# Out:
# array([ 0.  ,  2.38,  4.76,  7.14,  9.52, 11.9 ])

# %%
# Labels for each bin
labels=['0 <=x<2.38', '2.38<=x<4.76', '4.76<=x<7.14',
       '7.14<=x<9.52', '9.52<=x<11.9']

# %%
# Convert the numerical values into the categorical values
df['bins'] = pd.cut(df['CO(GT)'], bins=bins,
                    labels=labels, include_lowest=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9357 entries, 2004-03-10 18:00:00 to 2005-04-04 14:00:00
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO(GT)         9357 non-null   float64
#  1   PT08.S1(CO)    8991 non-null   float64
#  2   PT08.S2(NMHC)  8991 non-null   float64
#  3   NOx(GT)        7718 non-null   float64
#  4   PT08.S3(NOx)   8991 non-null   float64
#  5   NO2(GT)        7715 non-null   float64
#  6   PT08.S4(NO2)   8991 non-null   float64
#  7   PT08.S5(O3)    8991 non-null   float64
#  8   RH             8991 non-null   float64
#  9   AH             8991 non-null   float64
#  10  C6H6(GT)       9357 non-null   float64
#  11  bins           9357 non-null   category
# dtypes: category(1), float64(11)
# memory usage: 886.6 KB

# %%
# Print bins
df['bins'][:50]
# Out:
# Datetime
# 2004-03-10 18:00:00    2.38<=x<4.76
# 2004-03-10 19:00:00      0 <=x<2.38
# 2004-03-10 20:00:00      0 <=x<2.38
# 2004-03-10 21:00:00      0 <=x<2.38
# 2004-03-10 22:00:00      0 <=x<2.38
# 2004-03-10 23:00:00      0 <=x<2.38
# 2004-03-11 00:00:00      0 <=x<2.38
# 2004-03-11 01:00:00      0 <=x<2.38
# 2004-03-11 02:00:00      0 <=x<2.38
# 2004-03-11 03:00:00      0 <=x<2.38
# 2004-03-11 04:00:00      0 <=x<2.38
# 2004-03-11 05:00:00      0 <=x<2.38
# 2004-03-11 06:00:00      0 <=x<2.38
# 2004-03-11 07:00:00      0 <=x<2.38
# 2004-03-11 08:00:00      0 <=x<2.38
# 2004-03-11 09:00:00      0 <=x<2.38
# 2004-03-11 10:00:00      0 <=x<2.38
# 2004-03-11 11:00:00      0 <=x<2.38
# 2004-03-11 12:00:00      0 <=x<2.38
# 2004-03-11 13:00:00      0 <=x<2.38
# 2004-03-11 14:00:00    2.38<=x<4.76
# 2004-03-11 15:00:00      0 <=x<2.38
# 2004-03-11 16:00:00      0 <=x<2.38
# 2004-03-11 17:00:00    2.38<=x<4.76
# 2004-03-11 18:00:00    4.76<=x<7.14
# 2004-03-11 19:00:00    4.76<=x<7.14
# 2004-03-11 20:00:00    4.76<=x<7.14
# 2004-03-11 21:00:00    2.38<=x<4.76
# 2004-03-11 22:00:00      0 <=x<2.38
# 2004-03-11 23:00:00      0 <=x<2.38
# 2004-03-12 00:00:00      0 <=x<2.38
# 2004-03-12 01:00:00      0 <=x<2.38
# 2004-03-12 02:00:00      0 <=x<2.38
# 2004-03-12 03:00:00      0 <=x<2.38
# 2004-03-12 04:00:00      0 <=x<2.38
# 2004-03-12 05:00:00      0 <=x<2.38
# 2004-03-12 06:00:00      0 <=x<2.38
# 2004-03-12 07:00:00      0 <=x<2.38
# 2004-03-12 08:00:00    2.38<=x<4.76
# 2004-03-12 09:00:00    2.38<=x<4.76
# 2004-03-12 10:00:00    2.38<=x<4.76
# 2004-03-12 11:00:00    2.38<=x<4.76
# 2004-03-12 12:00:00      0 <=x<2.38
# 2004-03-12 13:00:00    2.38<=x<4.76
# 2004-03-12 14:00:00    2.38<=x<4.76
# 2004-03-12 15:00:00    2.38<=x<4.76
# 2004-03-12 16:00:00    2.38<=x<4.76
# 2004-03-12 17:00:00    2.38<=x<4.76
# 2004-03-12 18:00:00    2.38<=x<4.76
# 2004-03-12 19:00:00    2.38<=x<4.76
# Name: bins, dtype: category
# Categories (5, object): ['0 <=x<2.38' < '2.38<=x<4.76' < '4.76<=x<7.14' < '7.14<=x<9.52' < '9.52<=x<11.9']

# %%
# Visualize the histogram of bins
plt.hist(df['bins'], bins=5)
plt.show()

# %%
"""
Log Transform
"""

# Distribution of original data
sns.distplot(df['PT08.S3(NOx)'])
# Out:
# C:\Users\edwsq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PT08.S3(NOx)', ylabel='Density'>

# %%
# Calculate natural logarithm on 'CO(GT)' column
df['log'] = np.log10(df['PT08.S3(NOx)'])

# %%
# Min values for each column
df.min()
# Out:
# CO(GT)                  0.0
# PT08.S1(CO)           647.0
# PT08.S2(NMHC)         383.0
# NOx(GT)                 2.0
# PT08.S3(NOx)          322.0
# NO2(GT)                 2.0
# PT08.S4(NO2)          551.0
# PT08.S5(O3)           221.0
# RH                      9.2
# AH                   0.1847
# C6H6(GT)                0.0
# bins             0 <=x<2.38
# log                2.507856
# dtype: object

# %%
# Distribution after log transform
sns.distplot(df['log'])
plt.xlabel('log(PT08.S3(NoX))')
plt.show()
# Out:
# C:\Users\edwsq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
"""
One-hot Encoding
"""

# Make a dataset

emp_id = pd.Series([1, 2, 3, 4, 5])
gender = pd.Series(['Male', 'Female', 'Female', 'Male', 'Female'])
remarks = pd.Series(['Nice', 'Good', 'Great', 'Great', 'Nice'])

df_emp = pd.DataFrame()
df_emp['emp_id'] = emp_id
df_emp['gender'] = gender
df_emp['remarks'] = remarks

# %%
# Print DataFrame
df_emp
# Out:
#    emp_id  gender remarks
# 0       1    Male    Nice
# 1       2  Female    Good
# 2       3  Female   Great
# 3       4    Male   Great
# 4       5  Female    Nice

# %%
# Print unique values for each column
print(df_emp['emp_id'].unique())
print(df_emp['gender'].unique())
print(df_emp['remarks'].unique())
# Out:
# [1 2 3 4 5]
# ['Male' 'Female']
# ['Nice' 'Good' 'Great']

# %%
# One-hot encoding the categorial values
df_emp_encoded = pd.get_dummies(
    df_emp, columns = ['gender', 'remarks'])

df_emp_encoded
# Out:
#    emp_id  gender_Female  gender_Male  remarks_Good  remarks_Great  \
# 0       1              0            1             0              0
# 1       2              1            0             1              0
# 2       3              1            0             0              1
# 3       4              0            1             0              1
# 4       5              1            0             0              0
#
#    remarks_Nice
# 0             1
# 1             0
# 2             0
# 3             0
# 4             1

# %%
"""
Normalization
"""

# Visualize two columns of different scales
plt.plot(df['CO(GT)'], label='CO')
plt.plot(df['PT08.S2(NMHC)'], label='NMHC')
plt.legend(loc='best')

# %%
# Normalize the 'CO(GT)' column
co = df['CO(GT)'].copy()
co_max = co.max()
co_min = co.min()

df['CO_Norm'] = (co - co_min) / (co_max - co_min)
df['CO_Norm']
# Out:
# Datetime
# 2004-03-10 18:00:00    0.218487
# 2004-03-10 19:00:00    0.168067
# 2004-03-10 20:00:00    0.184874
# 2004-03-10 21:00:00    0.184874
# 2004-03-10 22:00:00    0.134454
#                          ...
# 2005-04-04 10:00:00    0.260504
# 2005-04-04 11:00:00    0.201681
# 2005-04-04 12:00:00    0.201681
# 2005-04-04 13:00:00    0.176471
# 2005-04-04 14:00:00    0.184874
# Name: CO_Norm, Length: 9357, dtype: float64

# %%
# Normalize the 'PT08.S2(NMHC)' column
nmhc = df['PT08.S2(NMHC)'].copy()
nmhc_max = nmhc.max()
nmhc_min = nmhc.min()

df['NMHC_Norm'] = (nmhc - nmhc_min) / (nmhc_max - nmhc_min)
df['NMHC_Norm']
# Out:
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backends\backend_qt5.py", line 480, in _draw_idle
#     self.draw()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2707, in draw
#     self._update_title_position(renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2638, in _update_title_position
#     bb = ax.xaxis.get_tightbbox(renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axis.py", line 1109, in get_tightbbox
#     ticks_to_draw = self._update_ticks()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axis.py", line 1021, in _update_ticks
#     major_locs = self.get_majorticklocs()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axis.py", line 1283, in get_majorticklocs
#     return self.major.locator()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 1325, in __call__
#     dmin, dmax = self.viewlim_to_dt()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 1080, in viewlim_to_dt
#     return num2date(vmin, self.tz), num2date(vmax, self.tz)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Datetime
# 2004-03-10 18:00:00    0.362097
# 2004-03-10 19:00:00    0.312398
# 2004-03-10 20:00:00    0.303659
# 2004-03-10 21:00:00    0.308575
# 2004-03-10 22:00:00    0.247406
#                          ...
# 2005-04-04 10:00:00    0.392135
# 2005-04-04 11:00:00    0.351720
# 2005-04-04 12:00:00    0.371382
# 2005-04-04 13:00:00    0.315674
# 2005-04-04 14:00:00    0.362643
# Name: NMHC_Norm, Length: 9357, dtype: float64

# %%
# Visualized normalized columns
plt.plot(df['CO_Norm'], label='CO (normalized)')
plt.plot(df['NMHC_Norm'], label='NMHC (normalized)')
plt.legend(loc='best')

# %%
"""
Feature Split
"""

# Make untidy movie data
movies = pd.Series(["The Godfather, 1972, Francis Ford Coppola",
                    "Contact, 1997, Robert Zemeckis",
                   "Parasite, 2019, Joon-ho Bong"])

movies
# Out:
# 0    The Godfather, 1972, Francis Ford Coppola
# 1               Contact, 1997, Robert Zemeckis
# 2                 Parasite, 2019, Joon-ho Bong
# dtype: object
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backends\backend_qt5.py", line 480, in _draw_idle
#     self.draw()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2707, in draw
#     self._update_title_position(renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2638, in _update_title_position
#     bb = ax.xaxis.get_tightbbox(renderer)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axis.py", line 1109, in get_tightbbox
#     ticks_to_draw = self._update_ticks()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axis.py", line 1021, in _update_ticks
#     major_locs = self.get_majorticklocs()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axis.py", line 1283, in get_majorticklocs
#     return self.major.locator()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 1325, in __call__
#     dmin, dmax = self.viewlim_to_dt()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 1080, in viewlim_to_dt
#     return num2date(vmin, self.tz), num2date(vmax, self.tz)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'

# %%
# Divide movie data into title, year, director columns

lst_title = []
lst_year = []
lst_director = []

for val in movies:
    title, year, director = val.split(',')  # data split
    lst_title.append(title)
    lst_year.append(year)
    lst_director.append(director)

print(lst_title)
print(lst_year)
print(lst_director)
# Out:
# ['The Godfather', 'Contact', 'Parasite']
# [' 1972', ' 1997', ' 2019']
# [' Francis Ford Coppola', ' Robert Zemeckis', ' Joon-ho Bong']

# %%
# Make a DataFrame object
df_movie = pd.DataFrame()
df_movie['title'] = lst_title
df_movie['year'] = lst_year
df_movie['director'] = lst_director

df_movie
# Out:
#            title   year               director
# 0  The Godfather   1972   Francis Ford Coppola
# 1        Contact   1997        Robert Zemeckis
# 2       Parasite   2019           Joon-ho Bong
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
# ...
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
# Traceback (most recent call last):
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 224, in process
#     func(*args, **kwargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2990, in mouse_move
#     s = event.inaxes.format_coord(event.xdata, event.ydata)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3701, in format_coord
#     xs = self.format_xdata(x)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 3683, in format_xdata
#     return (self.fmt_xdata if self.fmt_xdata is not None
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 278, in format_data_short
#     return self.format_data(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\ticker.py", line 270, in format_data
#     return self.__call__(value)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 928, in __call__
#     result = self._formatter(x, pos)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 605, in __call__
#     return num2date(x, self.tz).strftime(self.fmt)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 511, in num2date
#     return _from_ordinalf_np_vectorized(x, tz).tolist()
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2113, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\numpy\lib\function_base.py", line 2197, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "C:\Users\edwsq\anaconda3\lib\site-packages\matplotlib\dates.py", line 342, in _from_ordinalf
#     dt = dt.astimezone(tz)
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'UnitData'
